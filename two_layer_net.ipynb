# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the MNIST dataset.😀

# %%
#install requirements
# !pip install -r requirements.txt
# Out:
# Collecting attrs==19.1.0 (from -r requirements.txt (line 1))
#   Downloading attrs-19.1.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting backcall==0.1.0 (from -r requirements.txt (line 2))
#   Downloading backcall-0.1.0.zip (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bleach==3.1.0 (from -r requirements.txt (line 3))
#   Downloading bleach-3.1.0-py2.py3-none-any.whl.metadata (19 kB)
# Collecting certifi==2019.3.9 (from -r requirements.txt (line 4))
#   Downloading certifi-2019.3.9-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting chardet==3.0.4 (from -r requirements.txt (line 5))
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting colorama==0.4.1 (from -r requirements.txt (line 6))
#   Downloading colorama-0.4.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting cycler==0.10.0 (from -r requirements.txt (line 7))
#   Downloading cycler-0.10.0-py2.py3-none-any.whl.metadata (722 bytes)
# Collecting decorator==4.4.0 (from -r requirements.txt (line 8))
#   Downloading decorator-4.4.0-py2.py3-none-any.whl.metadata (3.7 kB)
# Collecting defusedxml==0.5.0 (from -r requirements.txt (line 9))
#   Downloading defusedxml-0.5.0-py2.py3-none-any.whl.metadata (29 kB)
# Collecting entrypoints==0.3 (from -r requirements.txt (line 10))
#   Downloading entrypoints-0.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting future==0.17.1 (from -r requirements.txt (line 11))
#   Downloading future-0.17.1.tar.gz (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.1/829.1 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gitdb2==2.0.5 (from -r requirements.txt (line 12))
#   Downloading gitdb2-2.0.5-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting GitPython==2.1.11 (from -r requirements.txt (line 13))
#   Downloading GitPython-2.1.11-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting idna==2.8 (from -r requirements.txt (line 14))
#   Downloading idna-2.8-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting ipykernel==5.1.0 (from -r requirements.txt (line 15))
#   Downloading ipykernel-5.1.0-py3-none-any.whl.metadata (937 bytes)
# Collecting ipython==7.4.0 (from -r requirements.txt (line 16))
#   Downloading ipython-7.4.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (0.2.0)
# Collecting ipywidgets==7.4.2 (from -r requirements.txt (line 18))
#   Downloading ipywidgets-7.4.2-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting imageio==2.8.0 (from -r requirements.txt (line 19))
#   Downloading imageio-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jedi==0.13.3 (from -r requirements.txt (line 20))
#   Downloading jedi-0.13.3-py2.py3-none-any.whl.metadata (14 kB)
# Collecting Jinja2==2.10 (from -r requirements.txt (line 21))
#   Downloading Jinja2-2.10-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonschema==3.0.1 (from -r requirements.txt (line 22))
#   Downloading jsonschema-3.0.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting jupyter==1.0.0 (from -r requirements.txt (line 23))
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting jupyter-client==5.2.4 (from -r requirements.txt (line 24))
#   Downloading jupyter_client-5.2.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting jupyter-console==6.0.0 (from -r requirements.txt (line 25))
#   Downloading jupyter_console-6.0.0-py2.py3-none-any.whl.metadata (955 bytes)
# Collecting jupyter-core==4.4.0 (from -r requirements.txt (line 26))
#   Downloading jupyter_core-4.4.0-py2.py3-none-any.whl.metadata (840 bytes)
# Collecting jupyterlab==0.35.4 (from -r requirements.txt (line 27))
#   Downloading jupyterlab-0.35.4-py3-none-any.whl.metadata (1.4 kB)
# Collecting jupyterlab-server==0.2.0 (from -r requirements.txt (line 28))
#   Downloading jupyterlab_server-0.2.0-py3-none-any.whl.metadata (977 bytes)
# Collecting kiwisolver==1.0.1 (from -r requirements.txt (line 29))
#   Downloading kiwisolver-1.0.1.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting MarkupSafe==1.1.1 (from -r requirements.txt (line 30))
#   Downloading MarkupSafe-1.1.1.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting matplotlib==3.0.3 (from -r requirements.txt (line 31))
#   Downloading matplotlib-3.0.3.tar.gz (36.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.6/36.6 MB 31.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mistune==0.8.4 (from -r requirements.txt (line 32))
#   Downloading mistune-0.8.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting nbconvert==5.4.1 (from -r requirements.txt (line 33))
#   Downloading nbconvert-5.4.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting nbdime==1.0.5 (from -r requirements.txt (line 34))
#   Downloading nbdime-1.0.5-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting nbformat==4.4.0 (from -r requirements.txt (line 35))
#   Downloading nbformat-4.4.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting notebook==5.7.8 (from -r requirements.txt (line 36))
#   Downloading notebook-5.7.8-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting numpy==1.16.2 (from -r requirements.txt (line 37))
#   Downloading numpy-1.16.2.zip (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 80.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pandocfilters==1.4.2 (from -r requirements.txt (line 38))
#   Downloading pandocfilters-1.4.2.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting parso==0.3.4 (from -r requirements.txt (line 39))
#   Downloading parso-0.3.4-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pexpect==4.6.0 (from -r requirements.txt (line 40))
#   Downloading pexpect-4.6.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 41)) (0.7.5)
# Collecting Pillow==6.0.0 (from -r requirements.txt (line 42))
#   Downloading Pillow-6.0.0.tar.gz (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 25.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting prometheus-client==0.6.0 (from -r requirements.txt (line 43))
#   Downloading prometheus_client-0.6.0.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting prompt-toolkit==2.0.9 (from -r requirements.txt (line 44))
#   Downloading prompt_toolkit-2.0.9-py3-none-any.whl.metadata (11 kB)
# Collecting ptyprocess==0.6.0 (from -r requirements.txt (line 45))
#   Downloading ptyprocess-0.6.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting Pygments==2.3.1 (from -r requirements.txt (line 46))
#   Downloading Pygments-2.3.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting pyparsing==2.3.1 (from -r requirements.txt (line 47))
#   Downloading pyparsing-2.3.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting pyrsistent==0.14.11 (from -r requirements.txt (line 48))
#   Downloading pyrsistent-0.14.11.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting python-dateutil==2.8.0 (from -r requirements.txt (line 49))
#   Downloading python_dateutil-2.8.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting pyzmq==18.0.1 (from -r requirements.txt (line 50))
#   Downloading pyzmq-18.0.1.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.1 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt # library for plotting figures

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `neural_net.py` to represent instances of our network.
# The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays.
#
# Here, PLEASE COPY your codes in `neural_net.py`. Fill all the blanks with your modified code.

# %%
from __future__ import print_function

import numpy as np

class TwoLayerNet(object):
  """
  A two-layer fully-connected neural network. The net has an input dimension of
  N, a hidden layer dimension of H, and performs classification over C classes.
  We train the network with a softmax loss function and L2 regularization on the
  weight matrices. The network uses a ReLU nonlinearity after the first fully
  connected layer.

  In other words, the network has the following architecture:

  input - fully connected layer - ReLU - fully connected layer - softmax

  The outputs of the second fully-connected layer are the scores for each class.
  """

  def __init__(self, input_size, hidden_size, output_size, std=1e-4):
    """
    Initialize the model. Weights are initialized to small random values and
    biases are initialized to zero. Weights and biases are stored in the
    variable self.params, which is a dictionary with the following keys:

    W1: First layer weights; has shape (D, H)
    b1: First layer biases; has shape (H,)
    W2: Second layer weights; has shape (H, C)
    b2: Second layer biases; has shape (C,)

    Inputs:
    - input_size: The dimension D of the input data.
    - hidden_size: The number of neurons H in the hidden layer.
    - output_size: The number of classes C.
    """
	# np.random.randn(shape)
	# - Return a sample (or samples) from the “standard normal” distribution following shape
    self.params = {}
    self.params['W1'] = std * np.random.randn(input_size, hidden_size)
    self.params['b1'] = np.zeros(hidden_size)
    self.params['W2'] = std * np.random.randn(hidden_size, output_size)
    self.params['b2'] = np.zeros(output_size)

  def loss(self, X, y=None, reg=0.0):
    """
    Compute the loss and gradients for a two layer fully connected neural
    network.

    Inputs:
    - X: Input data of shape (N, D). Each X[i] is a training sample.
    - y: Vector of training labels. y[i] is the label for X[i], and each y[i] is
      an integer in the range 0 <= y[i] < C. This parameter is optional; if it
      is not passed then we only return scores, and if it is passed then we
      instead return the loss and gradients.
    - reg: Regularization strength.

    Returns:
    If y is None, return a matrix scores of shape (N, C) where scores[i, c] is
    the score for class c on input X[i].

    If y is not None, instead return a tuple of:
    - loss: Loss (data loss and regularization loss) for this batch of training
      samples.
    - grads: Dictionary mapping parameter names to gradients of those parameters
      with respect to the loss function; has the same keys as self.params.
    """
    # Unpack variables from the params dictionary
    W1, b1 = self.params['W1'], self.params['b1']
    W2, b2 = self.params['W2'], self.params['b2']
    N, D = X.shape

    # Compute the forward pass
    scores = None
    #############################################################################
    # TODO: Perform the forward pass, computing the class scores for the input. #
    # Store the result in the scores variable, which should be an array of      #
    # shape (N, C).                                                             #
    #############################################################################
	# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    # First layer linear transformation
    L1 = X.dot(W1) + b1

    # ReLU
    L1_relu = np.maximum(0, L1)

    # Second (final) layer linear transformation
    L2 = L1_relu.dot(W2) + b2
    scores = L2

	# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################

    # If the targets are not given then jump out, we're done
    if y is None:
      return scores

    #############################################################################
    # TODO: Finish the forward pass, and compute the loss. This should include  #
    # both the data loss and L2 regularization for W1 and W2. Store the result  #
    # in the variable loss, which should be a scalar. Use the Softmax           #
    # classifier loss.                                                          #
    #############################################################################
	# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    # Softmax probabilities calculation
    norm_preds = scores - np.max(scores, axis=1, keepdims=True)
    exp_preds = np.exp(norm_preds)
    pred_probs = exp_preds / np.sum(exp_preds, axis=1, keepdims=True)

    # Loss calculation
    log_pred_prob = - np.log(pred_probs[np.arange(N), y])
    data_loss = np.mean(log_pred_prob)

    # Regularization (assuming lambda = 1/2 to simplify the gradient later)
    regu_loss = 0.5 * reg * (np.sum(W1*W1) + np.sum(W2*W2))
    loss = data_loss + regu_loss

	# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################

    # Backward pass: compute gradients
    grads = {}
    #############################################################################
    # TODO: Compute the backward pass, computing the derivatives of the weights #
    # and biases. Store the results in the grads dictionary. For example,       #
    # grads['W1'] should store the gradient on W1, and be a matrix of same size #
    #############################################################################
	# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    # Gradient based on scores
    der_scores = pred_probs
    der_scores[np.arange(N), y] -= 1
    der_scores /= N

    # Gradients for 2nd layer
    grads['W2'] = L1_relu.T.dot(der_scores)
    grads['b2'] = np.sum(der_scores, axis=0)
    grads['W2'] += reg * W2

    # Backpropagation
    der_L1_relu = der_scores.dot(W2.T)
    der_L1 = der_L1_relu
    der_L1[L1 < 0] = 0

    # Gradients for 1st layer
    grads['W1'] = X.T.dot(der_L1)
    grads['b1'] = np.sum(der_L1, axis=0)
    grads['W1'] += reg * W1

	# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################

    return loss, grads

  def train(self, X, y, X_val, y_val,
            learning_rate=1e-3, learning_rate_decay=0.95,
            reg=5e-6, num_iters=100,
            batch_size=200, verbose=False):
    """
    Train this neural network using stochastic gradient descent.

    Inputs:
    - X: A numpy array of shape (N, D) giving training data.
    - y: A numpy array f shape (N,) giving training labels; y[i] = c means that
      X[i] has label c, where 0 <= c < C.
    - X_val: A numpy array of shape (N_val, D) giving validation data.
    - y_val: A numpy array of shape (N_val,) giving validation labels.
    - learning_rate: Scalar giving learning rate for optimization.
    - learning_rate_decay: Scalar giving factor used to decay the learning rate
      after each epoch.
    - reg: Scalar giving regularization strength.
    - num_iters: Number of steps to take when optimizing.
    - batch_size: Number of training examples to use per step.
    - verbose: boolean; if true print progress during optimization.
    """
    num_train = X.shape[0]
    iterations_per_epoch = max(num_train / batch_size, 1)

    # Use SGD to optimize the parameters in self.model
    loss_history = []
    train_acc_history = []
    val_acc_history = []

    for it in range(num_iters):
      X_batch = None
      y_batch = None

      #########################################################################
      # TODO: Create a random minibatch of training data and labels, storing  #
      # them in X_batch and y_batch respectively.                             #
	  # - See [ np.random.choice ]											  #
      #########################################################################
	  # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

      idxs = np.random.choice(num_train, batch_size, replace=True)
      X_batch = X[idxs]
      y_batch = y[idxs]

	  # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
      #########################################################################
      #                             END OF YOUR CODE                          #
      #########################################################################

      # Compute loss and gradients using the current minibatch
      loss, grads = self.loss(X_batch, y=y_batch, reg=reg) # loss function you completed above
      loss_history.append(loss)

      #########################################################################
      # TODO: Use the gradients in the grads dictionary to update the         #
      # parameters of the network (stored in the dictionary self.params)      #
      # using stochastic gradient descent. You'll need to use the gradients   #
      # stored in the grads dictionary defined above.                         #
      #########################################################################
	  # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

      self.params['W1'] -= learning_rate * grads['W1']
      self.params['b1'] -= learning_rate * grads['b1']

      self.params['W2'] -= learning_rate * grads['W2']
      self.params['b2'] -= learning_rate * grads['b2']


	  # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
      #########################################################################
      #                             END OF YOUR CODE                          #
      #########################################################################

	  # print loss value per 100 epoch
      if verbose and it % 100 == 0:
        print('iteration %d / %d: loss %f' % (it, num_iters, loss))

      # Every epoch, check train and val accuracy and decay learning rate.
      if it % iterations_per_epoch == 0:
        # Check accuracy
        train_acc = (self.predict(X_batch) == y_batch).mean()
        val_acc = (self.predict(X_val) == y_val).mean()
        train_acc_history.append(train_acc)
        val_acc_history.append(val_acc)

        # Decay learning rate
        learning_rate *= learning_rate_decay

    return {
      'loss_history': loss_history,
      'train_acc_history': train_acc_history,
      'val_acc_history': val_acc_history,
    }

  def predict(self, X):
    """
    Use the trained weights of this two-layer network to predict labels for
    data points. For each data point we predict scores for each of the C
    classes, and assign each data point to the class with the highest score.

    Inputs:
    - X: A numpy array of shape (N, D) giving N D-dimensional data points to
      classify.

    Returns:
    - y_pred: A numpy array of shape (N,) giving predicted labels for each of
      the elements of X. For all i, y_pred[i] = c means that X[i] is predicted
      to have class c, where 0 <= c < C.
    """
    y_pred = None

    ###########################################################################
    # TODO: Implement this function; it should be VERY simple!                #
	# perform forward pass and return index of maximum scores				  #
    ###########################################################################
	# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    L1 = X.dot(self.params['W1']) + self.params['b1']
    L2 = (np.maximum(0, L1)).dot(self.params['W2']) + self.params['b2']

    y_pred = np.argmax(L2, axis=1)

	# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    ###########################################################################
    #                              END OF YOUR CODE                           #
    ###########################################################################

    return y_pred

# %% [markdown]
# Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# debug
print(X, y)
# Out:
# [[ 16.24345364  -6.11756414  -5.28171752 -10.72968622]
#  [  8.65407629 -23.01538697  17.44811764  -7.61206901]
#  [  3.19039096  -2.49370375  14.62107937 -20.60140709]
#  [ -3.22417204  -3.84054355  11.33769442 -10.99891267]
#  [ -1.72428208  -8.77858418   0.42213747   5.82815214]] [0 1 2 2 1]

# %% [markdown]
# # Forward pass: compute scores
# Open the file `classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Obtained loss:')
print(loss)
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Obtained loss:
# 1.2848224717239367
# Difference between your loss and correct loss:
# 0.01896541960606335

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 4.447625e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.02.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01714364353292381

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up MINST data so we can use it to train a classifier on a real dataset.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

def load_mnist_data():
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    x_train = x_train.reshape(-1, 28*28)
    x_test = x_test.reshape(-1, 28*28)

    return x_train, y_train, x_test, y_test

def split_data(x, y, validation_split=0.1):
    split_index = int((1 - validation_split) * len(x))
    x_train, x_val = x[:split_index], x[split_index:]
    y_train, y_val = y[:split_index], y[split_index:]
    return x_train, y_train, x_val, y_val

x_train, y_train, x_test, y_test = load_mnist_data()
x_train, y_train, x_val, y_val = split_data(x_train, y_train, validation_split=0.1)

print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# x_train shape: (54000, 784), y_train shape: (54000,)
# x_val shape: (6000, 784), y_val shape: (6000,)
# x_test shape: (10000, 784), y_test shape: (10000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 28 * 28
hidden_size = 100
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(x_train, y_train, x_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-2, learning_rate_decay=0.95,
            reg=1e-3, verbose=True)

# Predict on the validation set
val_acc = (net.predict(x_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302586
# iteration 100 / 1000: loss 2.302219
# iteration 200 / 1000: loss 2.301567
# iteration 300 / 1000: loss 2.301987
# iteration 400 / 1000: loss 2.299168
# iteration 500 / 1000: loss 2.301706
# iteration 600 / 1000: loss 2.301632
# iteration 700 / 1000: loss 2.302435
# iteration 800 / 1000: loss 2.301827
# iteration 900 / 1000: loss 2.298188
# Validation accuracy:  0.105

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.27 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(28, 28, 1, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 36% on the validation set. Our best network gets over 39% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (39% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$

# %%
best_net = None

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

learning_rates = [1e-3, 1e-2, 1e-1]
regularization = [1e-4, 1e-3, 1e-2, 1e-1]
hidden_sizes = [100, 200, 300]
iterations = [1000, 1500, 2000]

outcomes = {}
best_val_acc = -1

for lr in learning_rates:
  for reg in regularization:
    for h_size in hidden_sizes:
      for iters in iterations:
        net = TwoLayerNet(input_size, h_size, num_classes)
        stats = net.train(x_train, y_train, x_val, y_val,
                          learning_rate=lr, learning_rate_decay=0.95,
                          reg=reg, num_iters=iters, verbose=False)
        val_acc = stats['val_acc_history'][-1]
        outcomes[(lr, reg, h_size, iters)] = val_acc
        best_val_acc = max(best_val_acc, val_acc)
        if val_acc == best_val_acc:
          best_net = net

y_test_prediction = best_net.predict(x_test)
test_accuracy = np.mean(y_test == y_test_prediction)

print('Best validation accuracy: ', best_val_acc)
print('Best test accuracy: ', test_accuracy)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# Summary:  {(0.001, 0.0001, 100, 1000): np.float64(0.105), (0.001, 0.0001, 100, 1500): np.float64(0.105), (0.001, 0.0001, 100, 2000): np.float64(0.105), (0.001, 0.0001, 200, 1000): np.float64(0.105), (0.001, 0.0001, 200, 1500): np.float64(0.105), (0.001, 0.0001, 200, 2000): np.float64(0.105), (0.001, 0.0001, 300, 1000): np.float64(0.105), (0.001, 0.0001, 300, 1500): np.float64(0.105), (0.001, 0.0001, 300, 2000): np.float64(0.105), (0.001, 0.001, 100, 1000): np.float64(0.105), (0.001, 0.001, 100, 1500): np.float64(0.105), (0.001, 0.001, 100, 2000): np.float64(0.105), (0.001, 0.001, 200, 1000): np.float64(0.105), (0.001, 0.001, 200, 1500): np.float64(0.105), (0.001, 0.001, 200, 2000): np.float64(0.105), (0.001, 0.001, 300, 1000): np.float64(0.105), (0.001, 0.001, 300, 1500): np.float64(0.105), (0.001, 0.001, 300, 2000): np.float64(0.105), (0.001, 0.01, 100, 1000): np.float64(0.105), (0.001, 0.01, 100, 1500): np.float64(0.105), (0.001, 0.01, 100, 2000): np.float64(0.105), (0.001, 0.01, 200, 1000): np.float64(0.105), (0.001, 0.01, 200, 1500): np.float64(0.105), (0.001, 0.01, 200, 2000): np.float64(0.105), (0.001, 0.01, 300, 1000): np.float64(0.105), (0.001, 0.01, 300, 1500): np.float64(0.105), (0.001, 0.01, 300, 2000): np.float64(0.105), (0.001, 0.1, 100, 1000): np.float64(0.105), (0.001, 0.1, 100, 1500): np.float64(0.105), (0.001, 0.1, 100, 2000): np.float64(0.105), (0.001, 0.1, 200, 1000): np.float64(0.105), (0.001, 0.1, 200, 1500): np.float64(0.105), (0.001, 0.1, 200, 2000): np.float64(0.105), (0.001, 0.1, 300, 1000): np.float64(0.105), (0.001, 0.1, 300, 1500): np.float64(0.105), (0.001, 0.1, 300, 2000): np.float64(0.105), (0.01, 0.0001, 100, 1000): np.float64(0.105), (0.01, 0.0001, 100, 1500): np.float64(0.20066666666666666), (0.01, 0.0001, 100, 2000): np.float64(0.38816666666666666), (0.01, 0.0001, 200, 1000): np.float64(0.105), (0.01, 0.0001, 200, 1500): np.float64(0.21383333333333332), (0.01, 0.0001, 200, 2000): np.float64(0.504), (0.01, 0.0001, 300, 1000): np.float64(0.105), (0.01, 0.0001, 300, 1500): np.float64(0.216), (0.01, 0.0001, 300, 2000): np.float64(0.5021666666666667), (0.01, 0.001, 100, 1000): np.float64(0.105), (0.01, 0.001, 100, 1500): np.float64(0.20166666666666666), (0.01, 0.001, 100, 2000): np.float64(0.35583333333333333), (0.01, 0.001, 200, 1000): np.float64(0.105), (0.01, 0.001, 200, 1500): np.float64(0.2075), (0.01, 0.001, 200, 2000): np.float64(0.5206666666666667), (0.01, 0.001, 300, 1000): np.float64(0.105), (0.01, 0.001, 300, 1500): np.float64(0.20133333333333334), (0.01, 0.001, 300, 2000): np.float64(0.5193333333333333), (0.01, 0.01, 100, 1000): np.float64(0.105), (0.01, 0.01, 100, 1500): np.float64(0.20133333333333334), (0.01, 0.01, 100, 2000): np.float64(0.326), (0.01, 0.01, 200, 1000): np.float64(0.105), (0.01, 0.01, 200, 1500): np.float64(0.20133333333333334), (0.01, 0.01, 200, 2000): np.float64(0.42583333333333334), (0.01, 0.01, 300, 1000): np.float64(0.105), (0.01, 0.01, 300, 1500): np.float64(0.21766666666666667), (0.01, 0.01, 300, 2000): np.float64(0.5025), (0.01, 0.1, 100, 1000): np.float64(0.105), (0.01, 0.1, 100, 1500): np.float64(0.11783333333333333), (0.01, 0.1, 100, 2000): np.float64(0.24516666666666667), (0.01, 0.1, 200, 1000): np.float64(0.105), (0.01, 0.1, 200, 1500): np.float64(0.11933333333333333), (0.01, 0.1, 200, 2000): np.float64(0.24016666666666667), (0.01, 0.1, 300, 1000): np.float64(0.105), (0.01, 0.1, 300, 1500): np.float64(0.1985), (0.01, 0.1, 300, 2000): np.float64(0.222), (0.1, 0.0001, 100, 1000): np.float64(0.9186666666666666), (0.1, 0.0001, 100, 1500): np.float64(0.9313333333333333), (0.1, 0.0001, 100, 2000): np.float64(0.9393333333333334), (0.1, 0.0001, 200, 1000): np.float64(0.9175), (0.1, 0.0001, 200, 1500): np.float64(0.9288333333333333), (0.1, 0.0001, 200, 2000): np.float64(0.9371666666666667), (0.1, 0.0001, 300, 1000): np.float64(0.9198333333333333), (0.1, 0.0001, 300, 1500): np.float64(0.932), (0.1, 0.0001, 300, 2000): np.float64(0.9398333333333333), (0.1, 0.001, 1 ...
# Best validation accuracy:  0.9398333333333333
# Best test accuracy:  0.9301

# %%
# visualize the weights of the best network
print(best_net)
show_net_weights(best_net)
# Out:
# <__main__.TwoLayerNet object at 0x7f1558de8350>

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 50%.

# %%
test_acc = (best_net.predict(x_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.9301

# %%
sorted_outcomes = sorted(outcomes.items(), key=lambda x: x[1], reverse=True)

print("All hyperparameter configurations (sorted by validation accuracy):\n")
for (lr, reg, hidden_dim, num_iters), val_acc in sorted_outcomes:
    print(f"lr={lr}, reg={reg}, hidden_dim={hidden_dim}, iters={num_iters}  --> val_acc={val_acc:.3f}")

# The first entry in 'sorted_results' will be the best combination:
best_combination, best_acc = sorted_outcomes[0]
print("\nBest combination:", best_combination, "with validation accuracy:", best_acc)
# Out:
# All hyperparameter configurations (sorted by validation accuracy):
#
# lr=0.1, reg=0.0001, hidden_dim=300, iters=2000  --> val_acc=0.940
# lr=0.1, reg=0.0001, hidden_dim=100, iters=2000  --> val_acc=0.939
# lr=0.1, reg=0.001, hidden_dim=300, iters=2000  --> val_acc=0.939
# lr=0.1, reg=0.0001, hidden_dim=200, iters=2000  --> val_acc=0.937
# lr=0.1, reg=0.001, hidden_dim=200, iters=2000  --> val_acc=0.937
# lr=0.1, reg=0.001, hidden_dim=100, iters=2000  --> val_acc=0.936
# lr=0.1, reg=0.0001, hidden_dim=300, iters=1500  --> val_acc=0.932
# lr=0.1, reg=0.01, hidden_dim=300, iters=2000  --> val_acc=0.932
# lr=0.1, reg=0.0001, hidden_dim=100, iters=1500  --> val_acc=0.931
# lr=0.1, reg=0.001, hidden_dim=200, iters=1500  --> val_acc=0.931
# lr=0.1, reg=0.001, hidden_dim=300, iters=1500  --> val_acc=0.931
# lr=0.1, reg=0.0001, hidden_dim=200, iters=1500  --> val_acc=0.929
# lr=0.1, reg=0.001, hidden_dim=100, iters=1500  --> val_acc=0.929
# lr=0.1, reg=0.01, hidden_dim=100, iters=2000  --> val_acc=0.929
# lr=0.1, reg=0.01, hidden_dim=200, iters=2000  --> val_acc=0.927
# lr=0.1, reg=0.01, hidden_dim=300, iters=1500  --> val_acc=0.926
# lr=0.1, reg=0.01, hidden_dim=100, iters=1500  --> val_acc=0.925
# lr=0.1, reg=0.01, hidden_dim=200, iters=1500  --> val_acc=0.922
# lr=0.1, reg=0.001, hidden_dim=300, iters=1000  --> val_acc=0.921
# lr=0.1, reg=0.0001, hidden_dim=300, iters=1000  --> val_acc=0.920
# lr=0.1, reg=0.001, hidden_dim=200, iters=1000  --> val_acc=0.919
# lr=0.1, reg=0.0001, hidden_dim=100, iters=1000  --> val_acc=0.919
# lr=0.1, reg=0.01, hidden_dim=300, iters=1000  --> val_acc=0.919
# lr=0.1, reg=0.0001, hidden_dim=200, iters=1000  --> val_acc=0.917
# lr=0.1, reg=0.001, hidden_dim=100, iters=1000  --> val_acc=0.917
# lr=0.1, reg=0.01, hidden_dim=200, iters=1000  --> val_acc=0.915
# lr=0.1, reg=0.01, hidden_dim=100, iters=1000  --> val_acc=0.913
# lr=0.1, reg=0.1, hidden_dim=300, iters=2000  --> val_acc=0.880
# lr=0.1, reg=0.1, hidden_dim=100, iters=2000  --> val_acc=0.880
# lr=0.1, reg=0.1, hidden_dim=200, iters=1500  --> val_acc=0.879
# lr=0.1, reg=0.1, hidden_dim=300, iters=1500  --> val_acc=0.876
# lr=0.1, reg=0.1, hidden_dim=100, iters=1500  --> val_acc=0.874
# lr=0.1, reg=0.1, hidden_dim=100, iters=1000  --> val_acc=0.872
# lr=0.1, reg=0.1, hidden_dim=300, iters=1000  --> val_acc=0.868
# lr=0.1, reg=0.1, hidden_dim=200, iters=2000  --> val_acc=0.867
# lr=0.1, reg=0.1, hidden_dim=200, iters=1000  --> val_acc=0.863
# lr=0.01, reg=0.001, hidden_dim=200, iters=2000  --> val_acc=0.521
# lr=0.01, reg=0.001, hidden_dim=300, iters=2000  --> val_acc=0.519
# lr=0.01, reg=0.0001, hidden_dim=200, iters=2000  --> val_acc=0.504
# lr=0.01, reg=0.01, hidden_dim=300, iters=2000  --> val_acc=0.502
# lr=0.01, reg=0.0001, hidden_dim=300, iters=2000  --> val_acc=0.502
# lr=0.01, reg=0.01, hidden_dim=200, iters=2000  --> val_acc=0.426
# lr=0.01, reg=0.0001, hidden_dim=100, iters=2000  --> val_acc=0.388
# lr=0.01, reg=0.001, hidden_dim=100, iters=2000  --> val_acc=0.356
# lr=0.01, reg=0.01, hidden_dim=100, iters=2000  --> val_acc=0.326
# lr=0.01, reg=0.1, hidden_dim=100, iters=2000  --> val_acc=0.245
# lr=0.01, reg=0.1, hidden_dim=200, iters=2000  --> val_acc=0.240
# lr=0.01, reg=0.1, hidden_dim=300, iters=2000  --> val_acc=0.222
# lr=0.01, reg=0.01, hidden_dim=300, iters=1500  --> val_acc=0.218
# lr=0.01, reg=0.0001, hidden_dim=300, iters=1500  --> val_acc=0.216
# lr=0.01, reg=0.0001, hidden_dim=200, iters=1500  --> val_acc=0.214
# lr=0.01, reg=0.001, hidden_dim=200, iters=1500  --> val_acc=0.207
# lr=0.01, reg=0.001, hidden_dim=100, iters=1500  --> val_acc=0.202
# lr=0.01, reg=0.001, hidden_dim=300, iters=1500  --> val_acc=0.201
# lr=0.01, reg=0.01, hidden_dim=100, iters=1500  --> val_acc=0.201
# lr=0.01, reg=0.01, hidden_dim=200, iters=1500  --> val_acc=0.201
# lr=0.01, reg=0.0001, hidden_dim=100, iters=1500  --> val_acc=0.201
# lr=0.01, reg=0.1, hidden_dim=300, iters=1500  --> val_acc=0.199
# lr=0.01, reg=0.1, hidden_dim=200, iters=1500  --> val_acc=0.119
# lr=0.01, reg=0.1, hidden_dim=100, iters=1500  --> val_acc=0.118
# lr=0.001, reg=0.0001, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=100, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=100, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=200, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=200, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=300, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.0001, hidden_dim=300, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=100, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=100, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=200, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=200, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=300, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.001, hidden_dim=300, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=100, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=100, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=200, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=200, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=300, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.01, hidden_dim=300, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=100, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=100, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=200, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=200, iters=2000  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=300, iters=1500  --> val_acc=0.105
# lr=0.001, reg=0.1, hidden_dim=300, iters=2000  --> val_acc=0.105
# lr=0.01, reg=0.0001, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.0001, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.0001, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.001, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.001, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.001, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.01, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.01, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.01, hidden_dim=300, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.1, hidden_dim=100, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.1, hidden_dim=200, iters=1000  --> val_acc=0.105
# lr=0.01, reg=0.1, hidden_dim=300, iters=1000  --> val_acc=0.105
#
# Best combination: (0.1, 0.0001, 300, 2000) with validation accuracy: 0.9398333333333333

# %%
print("Available parameters:", best_net.params.keys())

# Inspect shapes and a few statistics:
print("W1 shape:", best_net.params['W1'].shape)
print("Mean of W1:", np.mean(best_net.params['W1']))
print("b1 shape:", best_net.params['b1'].shape)

# Same for W2, b2, etc.
print("W2 shape:", best_net.params['W2'].shape)
print("Mean of W2:", np.mean(best_net.params['W2']))
# Out:
# Available parameters: dict_keys(['W1', 'b1', 'W2', 'b2'])
# W1 shape: (784, 300)
# Mean of W1: 0.0012303920184166932
# b1 shape: (300,)
# W2 shape: (300, 10)
# Mean of W2: -3.093301342376268e-07

# %%
import matplotlib.pyplot as plt

plt.hist(best_net.params['W1'].ravel(), bins=50)
plt.title("Distribution of W1 values")
plt.show()
